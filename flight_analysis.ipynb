# %% [markdown]
# # Nama Kelompok
# - Akmal Muzakki Bakir (1305210087)
# - Namira Salsabilla (1305210091)
# - Haura Adzkia Delfina (1305213006)

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Import library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Airport Dataset

# %%
df1 = pd.read_csv('Airport Codes Dataset.csv', delimiter=';')
df1
# Out:
#      airport_id          city state                                  name
# 0         10165   Adak Island    AK                                  Adak
# 1         10299     Anchorage    AK   Ted Stevens Anchorage International
# 2         10304         Aniak    AK                         Aniak Airport
# 3         10754        Barrow    AK       Wiley Post/Will Rogers Memorial
# 4         10551        Bethel    AK                        Bethel Airport
# ..          ...           ...   ...                                   ...
# 360       11233      Cheyenne    WY   Cheyenne Regional/Jerry Olson Field
# 361       11097          Cody    WY                  Yellowstone Regional
# 362       11865      Gillette    WY              Gillette Campbell County
# 363       12441       Jackson    WY                          Jackson Hole
# 364       14543  Rock Springs    WY        Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
# mengecek apakah ada data yang kosong
df1.isnull().sum()
# Out:
# airport_id    0
# city          0
# state         0
# name          0
# dtype: int64

# %%
df1['airport_id'].nunique()
# Out:
# 365

# %%
# Mengubah tipe data airport menjadi string
df1['airport_id'] = df1['airport_id'].astype(str)

# %% [markdown]
# ## Flight on Time Dataset

# %%
df2 = pd.read_csv('Flight on-time performance _Raw_.csv')
df2 = df2.drop(['Cancelled', 'Diverted', 'DepDel15', 'ArrDel15'], axis=1)
df2.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 0  2011        4     10           6          4      WN            13495
# 1  2011        4     10           6          4      WN            13495
# 2  2011        4     10           6          4      WN            13495
# 3  2011        4     10           6          4      WN            13495
# 4  2011        4     10           6          4      WN            13495
#
#    DestAirportID  CRSDepTime DepTimeBlk  DepDelay  CRSArrTime ArrTimeBlk  \
# 0          12191        1435  1400-1459       2.0        1550  1500-1559
# 1          12191        1330  1300-1359      -4.0        1445  1400-1459
# 2          12191        1030  1000-1059      -2.0        1145  1100-1159
# 3          12889        1900  1900-1959       0.0        2055  2000-2059
# 4          12889        1340  1300-1359      -1.0        1530  1500-1559
#
#    ArrDelay
# 0      -6.0
# 1     -12.0
# 2     -14.0
# 3      -6.0
# 4       2.0

# %%
df2['OriginAirportID'] = df2['OriginAirportID'].astype(str)
df2.dtypes
# Out:
# Year                 int64
# Quarter              int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# Carrier             object
# OriginAirportID     object
# DestAirportID        int64
# CRSDepTime           int64
# DepTimeBlk          object
# DepDelay           float64
# CRSArrTime           int64
# ArrTimeBlk          object
# ArrDelay           float64
# dtype: object

# %%
# mengecek apakah ada data yang kosong
df2.isnull().sum()
# Out:
# Year                  0
# Quarter               0
# Month                 0
# DayofMonth            0
# DayOfWeek             0
# Carrier               0
# OriginAirportID       0
# DestAirportID         0
# CRSDepTime            0
# DepTimeBlk            0
# DepDelay           3697
# CRSArrTime            0
# ArrTimeBlk            0
# ArrDelay           4717
# dtype: int64

# %%
# Drop data yang mempunyai missing value
df2 = df2.dropna()
df2.isnull().sum()
# Out:
# Year               0
# Quarter            0
# Month              0
# DayofMonth         0
# DayOfWeek          0
# Carrier            0
# OriginAirportID    0
# DestAirportID      0
# CRSDepTime         0
# DepTimeBlk         0
# DepDelay           0
# CRSArrTime         0
# ArrTimeBlk         0
# ArrDelay           0
# dtype: int64

# %%
df2.dtypes
# Out:
# Year                 int64
# Quarter              int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# Carrier             object
# OriginAirportID     object
# DestAirportID        int64
# CRSDepTime           int64
# DepTimeBlk          object
# DepDelay           float64
# CRSArrTime           int64
# ArrTimeBlk          object
# ArrDelay           float64
# dtype: object

# %% [markdown]
# ## Weather Dataset

# %%
df3 = pd.read_csv('Weather Dataset.csv')
df3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\2043315392.py:1: DtypeWarning: Columns (7,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('Weather Dataset.csv')
#         AirportID  Year  Month  Day  Time  TimeZone          SkyCondition  \
# 0           14843  2013      4    1    56        -4  FEW018 SCT044 BKN070
# 1           14843  2013      4    1   156        -4         FEW037 SCT070
# 2           14843  2013      4    1   256        -4         FEW037 SCT070
# 3           14843  2013      4    1   356        -4         FEW025 SCT070
# 4           14843  2013      4    1   456        -4                FEW025
# ...           ...   ...    ...  ...   ...       ...                   ...
# 406511      11433  2013     10   31  2153        -5  SCT020 BKN035 OVC070
# 406512      11433  2013     10   31  2241        -5  BKN012 BKN035 OVC090
# 406513      11433  2013     10   31  2253        -5  BKN012 BKN045 OVC095
# ...

# %%
# mengecek apakah ada data yang kosong
df3.isnull().sum()
# Out:
# AirportID                0
# Year                     0
# Month                    0
# Day                      0
# Time                     0
# TimeZone                 0
# SkyCondition             0
# Visibility               0
# WeatherType              0
# DryBulbFarenheit         0
# DryBulbCelsius           0
# WetBulbFarenheit         0
# WetBulbCelsius           0
# DewPointFarenheit        0
# DewPointCelsius          0
# RelativeHumidity         0
# WindSpeed                0
# WindDirection            0
# ValueForWindCharacter    0
# StationPressure          0
# PressureTendency         0
# PressureChange           0
# SeaLevelPressure         0
# RecordType               0
# HourlyPrecip             0
# Altimeter                0
# dtype: int64

# %%
# mengubah tipe data atribut AirportID menjadi string
df3['AirportID'] = df3['AirportID'].astype(str)

# %%
# Mengecek tipe data tiap atribut
df3.dtypes
# Out:
# AirportID                object
# Year                      int64
# Month                     int64
# Day                       int64
# Time                      int64
# TimeZone                  int64
# SkyCondition             object
# Visibility               object
# WeatherType              object
# DryBulbFarenheit         object
# DryBulbCelsius           object
# WetBulbFarenheit         object
# WetBulbCelsius           object
# DewPointFarenheit        object
# DewPointCelsius          object
# RelativeHumidity         object
# WindSpeed                object
# WindDirection            object
# ValueForWindCharacter    object
# StationPressure          object
# PressureTendency         object
# PressureChange           object
# SeaLevelPressure         object
# RecordType               object
# HourlyPrecip             object
# Altimeter                object
# dtype: object

# %%
# Mengecek missing value di data bertipe data object
string_columns = df3.select_dtypes(include=['object']).columns
for col in string_columns:
    print(col, df3[col].isnull().sum())
# Out:
# AirportID 0
# SkyCondition 0
# Visibility 0
# WeatherType 0
# DryBulbFarenheit 0
# DryBulbCelsius 0
# WetBulbFarenheit 0
# WetBulbCelsius 0
# DewPointFarenheit 0
# DewPointCelsius 0
# RelativeHumidity 0
# WindSpeed 0
# WindDirection 0
# ValueForWindCharacter 0
# StationPressure 0
# PressureTendency 0
# PressureChange 0
# SeaLevelPressure 0
# RecordType 0
# HourlyPrecip 0
# Altimeter 0

# %% [markdown]
# ## Penggabungan Dataset Airport codes dengan Dataset Flight on Time

# %%
df2 = pd.merge(df2, df1, left_on='OriginAirportID', right_on='airport_id', suffixes=('_Flight', '_Airport'))
df2.drop_duplicates(inplace=True)
df2
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek Carrier OriginAirportID  \
# 0       2011        4     10           6          4      WN           13495
# 1       2011        4     10           6          4      WN           13495
# 2       2011        4     10           6          4      WN           13495
# 3       2011        4     10           6          4      WN           13495
# 4       2011        4     10           6          4      WN           13495
# ...      ...      ...    ...         ...        ...     ...             ...
# 499675  2011        4     10          29          6      B6           14254
# 499676  2011        4     10          30          7      B6           14254
# 499677  2011        4     10          30          7      B6           14254
# 499678  2011        4     10          31          1      B6           14254
# 499679  2011        4     10          31          1      B6           14254
#
# ...

# %%
# Drop kolom airport_id
df2.drop(['airport_id'], axis=1, inplace=True)
df2
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek Carrier OriginAirportID  \
# 0       2011        4     10           6          4      WN           13495
# 1       2011        4     10           6          4      WN           13495
# 2       2011        4     10           6          4      WN           13495
# 3       2011        4     10           6          4      WN           13495
# 4       2011        4     10           6          4      WN           13495
# ...      ...      ...    ...         ...        ...     ...             ...
# 499675  2011        4     10          29          6      B6           14254
# 499676  2011        4     10          30          7      B6           14254
# 499677  2011        4     10          30          7      B6           14254
# 499678  2011        4     10          31          1      B6           14254
# 499679  2011        4     10          31          1      B6           14254
#
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Preprocessing keterlambatan penerbangan berdasarkan keadaan cuaca

# %%
# Mangambil nilai depdelay yang negatif
df2_1 = df2[['OriginAirportID', 'DepDelay']]
df2_1 = df2_1[df2_1['DepDelay'] < 0]
df2_1.drop_duplicates(inplace=True)
df2_1
# Out:
#        OriginAirportID  DepDelay
# 1                13495      -4.0
# 2                13495      -2.0
# 4                13495      -1.0
# 10               13495      -5.0
# 29               13495      -6.0
# ...                ...       ...
# 499635           14254     -20.0
# 499637           14254      -7.0
# 499645           14254     -16.0
# 499648           14254      -2.0
# 499659           14254      -3.0
#
# [4453 rows x 2 columns]

# %%
# mengambil atribut airportID dan skycondition
df3_1 = df3[['AirportID', 'SkyCondition']]
df3_1.drop_duplicates(inplace=True)
df3_1
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\1482734635.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_1.drop_duplicates(inplace=True)
#        AirportID          SkyCondition
# 0          14843  FEW018 SCT044 BKN070
# 1          14843         FEW037 SCT070
# 3          14843         FEW025 SCT070
# 4          14843                FEW025
# 5          14843         FEW025 SCT080
# ...          ...                   ...
# 406507     11433  FEW006 BKN010 OVC025
# 406509     11433  SCT008 BKN025 OVC075
# 406510     11433  SCT020 BKN035 OVC070
# 406512     11433  BKN012 BKN035 OVC090
# 406513     11433  BKN012 BKN045 OVC095
#
# [157143 rows x 2 columns]

# %%
df2_1['DepDelay'].dtypes
# Out:
# dtype('float64')

# %%
# penggabungan data flight dan weather berdasarkan id yang sama
merged1 = pd.merge(df2_1, df3_1, left_on='OriginAirportID', right_on='AirportID', suffixes=('_flight', '_weather'))
res1 = merged1[['DepDelay', 'SkyCondition']]
res1.drop_duplicates(inplace=True)
res1
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3518555412.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res1.drop_duplicates(inplace=True)
#          DepDelay          SkyCondition
# 0            -4.0                BKN004
# 1            -4.0                OVC004
# 2            -4.0                    VV
# 3            -4.0                   OVC
# 4            -4.0  BKN004 BKN008 BKN047
# ...           ...                   ...
# 2787695     -16.0  FEW015 BKN030 OVC055
# 2787696     -16.0  FEW015 BKN028 OVC039
# 2787697     -16.0  FEW015 BKN032 OVC045
# 2787698     -16.0  SCT015 BKN026 OVC045
# 2787700     -16.0  FEW015 SCT024 OVC034
#
# [1537479 rows x 2 columns]

# %%
# Menggabungkan nilai skyCondition berdasrkan rata-rata dari setiap atribut
res1 = res1.groupby(['SkyCondition']).mean().reset_index()
res1
# Out:
#                SkyCondition   DepDelay
# 0                       BKN -12.391304
# 1                    BKN001 -12.260870
# 2             BKN001 BKN003  -9.000000
# 3      BKN001 BKN003 OVC050  -9.000000
# 4      BKN001 BKN003 OVC120  -9.000000
# ...                     ...        ...
# 82821                 VV014 -10.052632
# 82822                 VV015  -9.611111
# 82823                 VV016 -10.052632
# 82824                 VV017  -9.611111
# 82825                 VV020  -9.000000
#
# [82826 rows x 2 columns]

# %%
# mengubah tipe data SkyCondition menjadi kategori
res1['SkyCondition'] = res1['SkyCondition'].astype('category')
res1.dtypes
# Out:
# SkyCondition    category
# DepDelay         float64
# dtype: object

# %%
# Mengambil 3 huruf didepan pada atribut SkyCondition
res1['SkyCondition'] = res1['SkyCondition'].str[:3]
res1
# Out:
#       SkyCondition   DepDelay
# 0              BKN -12.391304
# 1              BKN -12.260870
# 2              BKN  -9.000000
# 3              BKN  -9.000000
# 4              BKN  -9.000000
# ...            ...        ...
# 82821          VV0 -10.052632
# 82822          VV0  -9.611111
# 82823          VV0 -10.052632
# 82824          VV0  -9.611111
# 82825          VV0  -9.000000
#
# [82826 rows x 2 columns]

# %%
# menghitung rata-rata depDelay berdasarkan SkyCondition
res1 = res1.groupby(['SkyCondition']).mean().reset_index()
res1
# Out:
#   SkyCondition   DepDelay
# 0          BKN -10.045542
# 1          CLR  -9.705683
# 2          FEW -10.088847
# 3            M -14.333333
# 4          OVC -13.238743
# 5          SCT  -9.855048
# 6           VV -10.000000
# 7          VV0 -10.996256

# %% [markdown]
# ## Preprocessing keterlambatan dengan mempertimbangkan faktor suhu udara dan aliansi penerbangan

# %%
# Mengambil data OriginAirportID, DepDelay, dan Carrier yang memiliki nilai depdelay negatif
df2_2 = df2[['OriginAirportID', 'DepDelay', 'Carrier']]
df2_2 = df2_2[df2_2['DepDelay'] < 0]
df2_2.drop_duplicates(inplace=True)
df2_2
# Out:
#        OriginAirportID  DepDelay Carrier
# 1                13495      -4.0      WN
# 2                13495      -2.0      WN
# 4                13495      -1.0      WN
# 10               13495      -5.0      WN
# 29               13495      -6.0      WN
# ...                ...       ...     ...
# 499635           14254     -20.0      B6
# 499637           14254      -7.0      B6
# 499645           14254     -16.0      B6
# 499648           14254      -2.0      B6
# 499659           14254      -3.0      B6
#
# [15826 rows x 3 columns]

# %%
# mengambil data airportID dan wetbulbfarenheit
df3_2 = df3[['AirportID', 'WetBulbFarenheit']]
df3_2.drop_duplicates(inplace=True)
df3_2
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3693982533.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_2.drop_duplicates(inplace=True)
#        AirportID WetBulbFarenheit
# 0          14843               74
# 1          14843               73
# 3          14843               72
# 5          14843               71
# 12         14843               75
# ...          ...              ...
# 393432     14057               33
# 400716     13795               32
# 400724     13795               31
# 400726     13795               29
# 400738     13795               30
#
# [3065 rows x 2 columns]

# %%
# menampilkan carrier yang berbeda
df2_2['Carrier'].unique()
# Out:
# array(['WN', 'XE', 'YV', 'OO', 'UA', 'US', 'DL', 'F9', 'FL', 'AA', 'B6',
#        'CO', 'HA', 'AS', 'EV', 'MQ'], dtype=object)

# %%
# menampilkan tipe data tiap atribut
df3_2.dtypes
# Out:
# AirportID           object
# WetBulbFarenheit    object
# dtype: object

# %%
# mengubah isi dari atribut WetBulbFarenheit yang bernilai M menjadi 0
df3_2['WetBulbFarenheit'] = df3_2['WetBulbFarenheit'].replace('M', 0).astype('float')
df3_2
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\2704846357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_2['WetBulbFarenheit'] = df3_2['WetBulbFarenheit'].replace('M', 0).astype('float')
#        AirportID  WetBulbFarenheit
# 0          14843              74.0
# 1          14843              73.0
# 3          14843              72.0
# 5          14843              71.0
# 12         14843              75.0
# ...          ...               ...
# 393432     14057              33.0
# 400716     13795              32.0
# 400724     13795              31.0
# 400726     13795              29.0
# 400738     13795              30.0
#
# [3065 rows x 2 columns]

# %%
# membuat rata-rata wetbulbfarenheit berdasarkan airportID
df3_2 = df3_2.groupby(['AirportID']).mean().reset_index()
df3_2
# Out:
#    AirportID  WetBulbFarenheit
# 0      10140         43.553191
# 1      10299         35.383333
# 2      10397         54.833333
# 3      10423         55.760870
# 4      10529         50.596491
# ..       ...               ...
# 61     14893         56.619048
# 62     14908         57.264706
# 63     15016         51.545455
# 64     15304         64.354839
# 65     15376         51.673913
#
# [66 rows x 2 columns]

# %%
# Merge data flight dan weather berdasarkan id yang sama
merged2 = pd.merge(df2_2, df3_2, left_on='OriginAirportID', right_on='AirportID', suffixes=('_flight', '_weather'))
res2 = merged2[['OriginAirportID', 'DepDelay', 'Carrier', 'WetBulbFarenheit']]
res2.drop_duplicates(inplace=True)
res2
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3222484394.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res2.drop_duplicates(inplace=True)
#      OriginAirportID  DepDelay Carrier  WetBulbFarenheit
# 0              13495      -4.0      WN         61.425000
# 1              13495      -2.0      WN         61.425000
# 2              13495      -1.0      WN         61.425000
# 3              13495      -5.0      WN         61.425000
# 4              13495      -6.0      WN         61.425000
# ...              ...       ...     ...               ...
# 8243           10299     -10.0      CO         35.383333
# 8244           10299      -1.0      CO         35.383333
# 8245           10299     -14.0      CO         35.383333
# 8246           10299     -12.0      CO         35.383333
# ...

# %%
# menghitung rata-rata depDelay dan wetbulbfarenheit berdasarkan carrier
res2 = res2.groupby(['Carrier']).mean().reset_index()
res2 = res2.sort_values(by=['DepDelay'])
res2
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\2125533029.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res2 = res2.groupby(['Carrier']).mean().reset_index()
#    Carrier  DepDelay  WetBulbFarenheit
# 1       AS -8.414062         54.943510
# 10      OO -8.227806         53.083546
# 15      YV -8.066922         54.576044
# 9       MQ -7.922689         52.800974
# 7       FL -7.770492         55.640666
# 14      XE -7.764133         53.008337
# 2       B6 -7.609756         56.011083
# 12      US -7.349185         55.044181
# 8       HA -7.250000         57.328942
# 5       EV -7.125571         53.999125
# 3       CO -7.074856         55.041088
# 6       F9 -7.023936         53.596812
# 4       DL -6.866935         54.524006
# 0       AA -6.808298         54.923884
# ...

# %%
# Kelompokkan carrier berdasarkan aliansi
res2['Aliance'] = np.where(res2['Carrier'].isin(['US', 'UA']), 'Star Alliance', 
                           np.where(res2['Carrier'].isin(['CO', 'DL']), 'Sky Team', 
                                    np.where(res2['Carrier'].isin(['WN', 'FL']), 'Southwest', 
                                             'Others')))
res2
# Out:
#    Carrier  DepDelay  WetBulbFarenheit        Aliance
# 1       AS -8.414062         54.943510         Others
# 10      OO -8.227806         53.083546         Others
# 15      YV -8.066922         54.576044         Others
# 9       MQ -7.922689         52.800974         Others
# 7       FL -7.770492         55.640666      Southwest
# 14      XE -7.764133         53.008337         Others
# 2       B6 -7.609756         56.011083         Others
# 12      US -7.349185         55.044181  Star Alliance
# 8       HA -7.250000         57.328942         Others
# 5       EV -7.125571         53.999125         Others
# 3       CO -7.074856         55.041088       Sky Team
# 6       F9 -7.023936         53.596812         Others
# 4       DL -6.866935         54.524006       Sky Team
# 0       AA -6.808298         54.923884         Others
# 11      UA -6.681004         54.171791  Star Alliance
# 13      WN -4.968182         54.010090      Southwest

# %%
res2 = res2.groupby(['Aliance']).mean().reset_index()
res2
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\535845343.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res2 = res2.groupby(['Aliance']).mean().reset_index()
#          Aliance  DepDelay  WetBulbFarenheit
# 0         Others -7.621317         54.427226
# 1       Sky Team -6.970896         54.782547
# 2      Southwest -6.369337         54.825378
# 3  Star Alliance -7.015094         54.607986

# %% [markdown]
# ## Preprocessing keterlambatan penerbangan berdasarkan waktu terhadap kombinasi arah angin

# %%
# mengambil data OriginAirportID, Year, Month, DayofMonth, dan DepDelay
df2_3 = df2[['OriginAirportID', 'Year', 'Month', 'DayofMonth', 'DepDelay']]
df2_3.drop_duplicates(inplace=True)
df2_3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\4215711510.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_3.drop_duplicates(inplace=True)
#        OriginAirportID  Year  Month  DayofMonth  DepDelay
# 0                13495  2011     10           6       2.0
# 1                13495  2011     10           6      -4.0
# 2                13495  2011     10           6      -2.0
# 3                13495  2011     10           6       0.0
# 4                13495  2011     10           6      -1.0
# ...                ...   ...    ...         ...       ...
# 499675           14254  2011     10          29     -13.0
# 499676           14254  2011     10          30     102.0
# 499677           14254  2011     10          30     -11.0
# ...

# %%
# menggabungkan bulan, tanggal, tahun ke dalam satu atribut baru
df2_3['Date'] = df2_3['Year'].astype(str) + '-' + df2_3['Month'].astype(str) + '-' + df2_3['DayofMonth'].astype(str)
df2_3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\28522212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_3['Date'] = df2_3['Year'].astype(str) + '-' + df2_3['Month'].astype(str) + '-' + df2_3['DayofMonth'].astype(str)
#        OriginAirportID  Year  Month  DayofMonth  DepDelay        Date
# 0                13495  2011     10           6       2.0   2011-10-6
# 1                13495  2011     10           6      -4.0   2011-10-6
# 2                13495  2011     10           6      -2.0   2011-10-6
# 3                13495  2011     10           6       0.0   2011-10-6
# 4                13495  2011     10           6      -1.0   2011-10-6
# ...                ...   ...    ...         ...       ...         ...
# ...

# %%
# mengubah tipe data atribut Date menjadi datetime
df2_3['Date'] = pd.to_datetime(df2_3['Date'])
# mengecek tipe data
df2_3.dtypes
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\1090033725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_3['Date'] = pd.to_datetime(df2_3['Date'])
# OriginAirportID            object
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepDelay                  float64
# Date               datetime64[ns]
# dtype: object

# %%
df2_3 = df2_3[['OriginAirportID', 'Date', 'DepDelay']]
df2_3.drop_duplicates(inplace=True)
df2_3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\58937937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_3.drop_duplicates(inplace=True)
#        OriginAirportID       Date  DepDelay
# 0                13495 2011-10-06       2.0
# 1                13495 2011-10-06      -4.0
# 2                13495 2011-10-06      -2.0
# 3                13495 2011-10-06       0.0
# 4                13495 2011-10-06      -1.0
# ...                ...        ...       ...
# 499675           14254 2011-10-29     -13.0
# 499676           14254 2011-10-30     102.0
# 499677           14254 2011-10-30     -11.0
# 499678           14254 2011-10-31     -10.0
# 499679           14254 2011-10-31     174.0
#
# [133683 rows x 3 columns]

# %%
# Ambil dep delay dibawah 0
df2_3 = df2_3[df2_3['DepDelay'] < 0]
df2_3
# Out:
#        OriginAirportID       Date  DepDelay
# 1                13495 2011-10-06      -4.0
# 2                13495 2011-10-06      -2.0
# 4                13495 2011-10-06      -1.0
# 10               13495 2011-10-06      -5.0
# 19               13495 2011-10-07      -1.0
# ...                ...        ...       ...
# 499672           14254 2011-10-27     -15.0
# 499673           14254 2011-10-28     -15.0
# 499675           14254 2011-10-29     -13.0
# 499677           14254 2011-10-30     -11.0
# 499678           14254 2011-10-31     -10.0
#
# [54573 rows x 3 columns]

# %%
df3_3 = df3[['AirportID', 'WindDirection']]
df3_3.drop_duplicates(inplace=True)
df3_3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\1107802877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_3.drop_duplicates(inplace=True)
#        AirportID WindDirection
# 0          14843           080
# 1          14843           090
# 2          14843           100
# 4          14843           110
# 14         14843           070
# ...          ...           ...
# 315125     10721             M
# 320864     13487             M
# 333525     14869             M
# 344548     12478             M
# 382957     10800           040
#
# [2533 rows x 2 columns]

# %%
df3_3['WindDirection'] = df3_3['WindDirection'].replace('VR ', 0)
df3_3['WindDirection'] = df3_3['WindDirection'].replace('M', 0)
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3686967017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_3['WindDirection'] = df3_3['WindDirection'].replace('VR ', 0)
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3686967017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_3['WindDirection'] = df3_3['WindDirection'].replace('M', 0)

# %%
# mengubah tipe data atribut WindDirection menjadi float
df3_3['WindDirection'] = df3_3['WindDirection'].astype('float')
df3_3.dtypes
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3508010598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_3['WindDirection'] = df3_3['WindDirection'].astype('float')
# AirportID         object
# WindDirection    float64
# dtype: object

# %%
# hitung rata-rata wind direction berdasarkan airport id
df3_3 = df3_3.groupby(['AirportID']).mean().reset_index()
df3_3
# Out:
#    AirportID  WindDirection
# 0      10140     175.263158
# 1      10299     175.263158
# 2      10397     175.263158
# 3      10423     170.769231
# 4      10529     170.769231
# ..       ...            ...
# 61     14893     175.263158
# 62     14908     175.263158
# 63     15016     170.769231
# 64     15304     170.769231
# 65     15376     170.769231
#
# [66 rows x 2 columns]

# %%
# menggabungkan data flight dan weather berdasarkan id yang sama
merged3 = pd.merge(df2_3, df3_3, left_on='OriginAirportID', right_on='AirportID', suffixes=('_flight', '_weather'))
res3 = merged3[['OriginAirportID', 'Date', 'WindDirection', 'DepDelay']]
res3.drop_duplicates(inplace=True)
res3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\4126074316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res3.drop_duplicates(inplace=True)
#       OriginAirportID       Date  WindDirection  DepDelay
# 0               13495 2011-10-06     175.263158      -4.0
# 1               13495 2011-10-06     175.263158      -2.0
# 2               13495 2011-10-06     175.263158      -1.0
# 3               13495 2011-10-06     175.263158      -5.0
# 4               13495 2011-10-07     175.263158      -1.0
# ...               ...        ...            ...       ...
# 23493           10299 2011-10-03     175.263158     -12.0
# 23494           10299 2011-10-02     175.263158      -4.0
# 23495           10299 2011-10-02     175.263158     -11.0
# ...

# %%
# Grupkan berdasrkan date
res3 = res3.groupby(['Date']).mean().reset_index()
res3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\1566648165.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res3 = res3.groupby(['Date']).mean().reset_index()
#          Date  WindDirection  DepDelay
# 0  2011-10-01     173.654437 -6.745695
# 1  2011-10-02     173.617116 -6.568783
# 2  2011-10-03     173.629004 -6.823377
# 3  2011-10-04     173.634124 -6.929825
# 4  2011-10-05     173.622695 -6.870013
# 5  2011-10-06     173.605595 -6.507503
# 6  2011-10-07     173.574134 -6.634309
# 7  2011-10-08     173.683226 -6.846255
# 8  2011-10-09     173.652944 -6.949045
# 9  2011-10-10     173.622588 -6.789267
# 10 2011-10-11     173.625914 -6.989912
# 11 2011-10-12     173.667171 -6.725000
# 12 2011-10-13     173.655548 -6.258475
# 13 2011-10-14     173.653206 -6.277856
# ...

# %%
# mengubah tipe data atribut Date menjadi datetime
res3['Date'] = pd.to_datetime(res3['Date'])
res3
# Out:
#          Date  WindDirection  DepDelay
# 0  2011-10-01     173.654437 -6.745695
# 1  2011-10-02     173.617116 -6.568783
# 2  2011-10-03     173.629004 -6.823377
# 3  2011-10-04     173.634124 -6.929825
# 4  2011-10-05     173.622695 -6.870013
# 5  2011-10-06     173.605595 -6.507503
# 6  2011-10-07     173.574134 -6.634309
# 7  2011-10-08     173.683226 -6.846255
# 8  2011-10-09     173.652944 -6.949045
# 9  2011-10-10     173.622588 -6.789267
# 10 2011-10-11     173.625914 -6.989912
# 11 2011-10-12     173.667171 -6.725000
# 12 2011-10-13     173.655548 -6.258475
# 13 2011-10-14     173.653206 -6.277856
# 14 2011-10-15     173.644196 -6.775564
# 15 2011-10-16     173.634941 -6.614267
# 16 2011-10-17     173.615165 -6.472900
# 17 2011-10-18     173.606893 -6.805412
# 18 2011-10-19     173.611142 -6.294781
# 19 2011-10-20     173.638651 -6.408333
# 20 2011-10-21     173.648485 -6.622517
# 21 2011-10-22     173.613618 -6.788312
# 22 2011-10-23     173.626846 -6.590489
# ...

# %%
# Membuat bins Date setiap kenaikan 5 hari
bins = pd.date_range(start='2011-10-01', end='2011-10-31', freq='6D')
labels = [str(bins[i]) + ' -- ' + str(bins[i+1]) for i in range(len(bins)-1)]

res3['Date bins'] = pd.cut(res3['Date'], bins=bins, labels=labels)
res3
# Out:
#          Date  WindDirection  DepDelay  \
# 0  2011-10-01     173.654437 -6.745695
# 1  2011-10-02     173.617116 -6.568783
# 2  2011-10-03     173.629004 -6.823377
# 3  2011-10-04     173.634124 -6.929825
# 4  2011-10-05     173.622695 -6.870013
# 5  2011-10-06     173.605595 -6.507503
# 6  2011-10-07     173.574134 -6.634309
# 7  2011-10-08     173.683226 -6.846255
# 8  2011-10-09     173.652944 -6.949045
# 9  2011-10-10     173.622588 -6.789267
# 10 2011-10-11     173.625914 -6.989912
# 11 2011-10-12     173.667171 -6.725000
# 12 2011-10-13     173.655548 -6.258475
# 13 2011-10-14     173.653206 -6.277856
# 14 2011-10-15     173.644196 -6.775564
# 15 2011-10-16     173.634941 -6.614267
# 16 2011-10-17     173.615165 -6.472900
# 17 2011-10-18     173.606893 -6.805412
# 18 2011-10-19     173.611142 -6.294781
# 19 2011-10-20     173.638651 -6.408333
# 20 2011-10-21     173.648485 -6.622517
# 21 2011-10-22     173.613618 -6.788312
# 22 2011-10-23     173.626846 -6.590489
# ...

# %%
# Mengubah tipe data atribut Date bins menjadi string
res3['Date bins'] = res3['Date bins'].astype(str)
res3
# Out:
#          Date  WindDirection  DepDelay  \
# 0  2011-10-01     173.654437 -6.745695
# 1  2011-10-02     173.617116 -6.568783
# 2  2011-10-03     173.629004 -6.823377
# 3  2011-10-04     173.634124 -6.929825
# 4  2011-10-05     173.622695 -6.870013
# 5  2011-10-06     173.605595 -6.507503
# 6  2011-10-07     173.574134 -6.634309
# 7  2011-10-08     173.683226 -6.846255
# 8  2011-10-09     173.652944 -6.949045
# 9  2011-10-10     173.622588 -6.789267
# 10 2011-10-11     173.625914 -6.989912
# 11 2011-10-12     173.667171 -6.725000
# 12 2011-10-13     173.655548 -6.258475
# 13 2011-10-14     173.653206 -6.277856
# 14 2011-10-15     173.644196 -6.775564
# 15 2011-10-16     173.634941 -6.614267
# 16 2011-10-17     173.615165 -6.472900
# 17 2011-10-18     173.606893 -6.805412
# 18 2011-10-19     173.611142 -6.294781
# 19 2011-10-20     173.638651 -6.408333
# 20 2011-10-21     173.648485 -6.622517
# 21 2011-10-22     173.613618 -6.788312
# 22 2011-10-23     173.626846 -6.590489
# ...

# %%
# Menghapus nilai jam pada Date bins serta mengganti nilai nan dengan 2011-10-01--2011-10-06
res3['Date bins'] = res3['Date bins'].str.replace('00:00:00', '')
res3['Date bins'] = res3['Date bins'].str.replace(' ', '')
res3['Date bins'] = res3['Date bins'].str.replace('nan', '2011-10-01--2011-10-07')
res3
# Out:
#          Date  WindDirection  DepDelay               Date bins
# 0  2011-10-01     173.654437 -6.745695  2011-10-01--2011-10-07
# 1  2011-10-02     173.617116 -6.568783  2011-10-01--2011-10-07
# 2  2011-10-03     173.629004 -6.823377  2011-10-01--2011-10-07
# 3  2011-10-04     173.634124 -6.929825  2011-10-01--2011-10-07
# 4  2011-10-05     173.622695 -6.870013  2011-10-01--2011-10-07
# 5  2011-10-06     173.605595 -6.507503  2011-10-01--2011-10-07
# 6  2011-10-07     173.574134 -6.634309  2011-10-01--2011-10-07
# 7  2011-10-08     173.683226 -6.846255  2011-10-07--2011-10-13
# 8  2011-10-09     173.652944 -6.949045  2011-10-07--2011-10-13
# 9  2011-10-10     173.622588 -6.789267  2011-10-07--2011-10-13
# 10 2011-10-11     173.625914 -6.989912  2011-10-07--2011-10-13
# 11 2011-10-12     173.667171 -6.725000  2011-10-07--2011-10-13
# 12 2011-10-13     173.655548 -6.258475  2011-10-07--2011-10-13
# 13 2011-10-14     173.653206 -6.277856  2011-10-13--2011-10-19
# ...

# %%
# Menggabungkan Date bins berdasarkan rata-rata wind direction dan dep delay
res3 = res3.groupby(['Date bins']).mean().reset_index()
res3
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3913185635.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res3 = res3.groupby(['Date bins']).mean().reset_index()
#                 Date bins  WindDirection  DepDelay
# 0  2011-10-01--2011-10-07     173.619587 -6.725643
# 1  2011-10-07--2011-10-13     173.651232 -6.759659
# 2  2011-10-13--2011-10-19     173.627590 -6.540130
# 3  2011-10-19--2011-10-25     173.622895 -6.649834
# 4  2011-10-25--2011-10-31     173.643151 -6.819560

# %% [markdown]
# ## Preprocessing keterlambatan penerbangan berdasarkan waktu keberangkatan dan kecepatan angin

# %%
# Mengambil data yang hanya berhubungan dengan airport code
df2_4 = df2[['OriginAirportID', 'CRSDepTime', 'DepDelay']]
df2_4.drop_duplicates(inplace=True)
df2_4
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\1568530308.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_4.drop_duplicates(inplace=True)
#        OriginAirportID  CRSDepTime  DepDelay
# 0                13495        1435       2.0
# 1                13495        1330      -4.0
# 2                13495        1030      -2.0
# 3                13495        1900       0.0
# 4                13495        1340      -1.0
# ...                ...         ...       ...
# 499674           14254         510       1.0
# 499676           14254         437     102.0
# 499677           14254         305     -11.0
# 499678           14254         437     -10.0
# 499679           14254         305     174.0
#
# [228363 rows x 3 columns]

# %%
# Mengambil data AirportID dan WindSpeed
df3_4 = df3[['AirportID', 'WindSpeed']]
df3_4.drop_duplicates(inplace=True)
df3_4
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\2692149233.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_4.drop_duplicates(inplace=True)
#        AirportID WindSpeed
# 0          14843        13
# 1          14843        10
# 2          14843         9
# 4          14843         7
# 8          14843        14
# ...          ...       ...
# 406201     11433        23
# 406336     11433        24
# 406337     11433        29
# 406340     11433        25
# 406341     11433        26
#
# [2082 rows x 2 columns]

# %%
# Merge data flight dan weather berdasarkan id yang sama
merged4 = pd.merge(df2_4, df3_4, left_on='OriginAirportID', right_on='AirportID', suffixes=('_df1', '_df3'))
res4 = merged4[['CRSDepTime', 'WindSpeed', 'DepDelay']]
res4.drop_duplicates(inplace=True)
res4
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3580130659.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res4.drop_duplicates(inplace=True)
#          CRSDepTime WindSpeed  DepDelay
# 0              1435        10       2.0
# 1              1435         9       2.0
# 2              1435         6       2.0
# 3              1435         8       2.0
# 4              1435         5       2.0
# ...             ...       ...       ...
# 5417734         100        20       0.0
# 5417735         100        14       0.0
# 5417736         100        21       0.0
# 5417775         603        26       1.0
# 5417817        2140        26      20.0
#
# [1895592 rows x 3 columns]

# %%
# Tampilkan data dengan DepDelay < 0
res4 = res4[res4['DepDelay'] < 0]
res4
# Out:
#          CRSDepTime WindSpeed  DepDelay
# 30             1330        10      -4.0
# 31             1330         9      -4.0
# 32             1330         6      -4.0
# 33             1330         8      -4.0
# 34             1330         5      -4.0
# ...             ...       ...       ...
# 5417648         100        24      -2.0
# 5417649         100        26      -2.0
# 5417650         100        20      -2.0
# 5417651         100        14      -2.0
# 5417652         100        21      -2.0
#
# [548369 rows x 3 columns]

# %%
res4['WindSpeed'] = res4['WindSpeed'].str.replace(' ', '0').str.replace('M', '0').astype('float')
res4.dtypes
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\3531435529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res4['WindSpeed'] = res4['WindSpeed'].str.replace(' ', '0').str.replace('M', '0').astype('float')
# CRSDepTime      int64
# WindSpeed     float64
# DepDelay      float64
# dtype: object

# %%
# Grupkan berdasarkan OriginAirportID
res4 = res4.groupby(['CRSDepTime']).mean().reset_index()
res4.sort_values(by=['DepDelay'])
# Out:
#       CRSDepTime  WindSpeed   DepDelay
# 862         1940  20.990604 -11.374506
# 877         1955  20.669903 -10.178355
# 879         1957  17.408696 -10.112319
# 18           330  15.333333 -10.000000
# 1083        2346  14.227273 -10.000000
# ...          ...        ...        ...
# 930         2048  17.892857  -2.500000
# 7             53  15.333333  -2.000000
# 1072        2323  19.333333  -2.000000
# 944         2104  18.285714  -2.000000
# 39           543  17.709677  -1.000000
#
# [1089 rows x 3 columns]

# %%
# Mengubah tipe data CRSDepTime menjadi string
res4['CRSDepTime'] = res4['CRSDepTime'].astype('str')

# %%
# Jika panjang nilai dari atribut = 2, maka tambahkan angka 00 di depannya
res4['CRSDepTime'] = res4['CRSDepTime'].apply(lambda x: '00' + x if len(x) == 2 else x)
res4['CRSDepTime'] = res4['CRSDepTime'].apply(lambda x: '0' + x if len(x) == 3 else x)
res4
# Out:
#      CRSDepTime  WindSpeed  DepDelay
# 0          0020  20.131367 -6.254400
# 1          0025  22.333333 -3.500000
# 2          0029  22.333333 -6.909091
# 3          0030  17.714286 -2.500000
# 4          0035  17.714286 -4.750000
# ...         ...        ...       ...
# 1084       2349  19.333333 -3.000000
# 1085       2350  18.897436 -5.509434
# 1086       2353  19.333333 -5.500000
# 1087       2355  18.328912 -6.381963
# 1088       2359  19.865385 -8.130923
#
# [1089 rows x 3 columns]

# %%
# Menambahkan . pada CRSDepTime
res4['CRSDepTime'] = res4['CRSDepTime'].apply(lambda x: x[:2] + ':' + x[2:])
res4
# Out:
#      CRSDepTime  WindSpeed  DepDelay
# 0         00:20  20.131367 -6.254400
# 1         00:25  22.333333 -3.500000
# 2         00:29  22.333333 -6.909091
# 3         00:30  17.714286 -2.500000
# 4         00:35  17.714286 -4.750000
# ...         ...        ...       ...
# 1084      23:49  19.333333 -3.000000
# 1085      23:50  18.897436 -5.509434
# 1086      23:53  19.333333 -5.500000
# 1087      23:55  18.328912 -6.381963
# 1088      23:59  19.865385 -8.130923
#
# [1089 rows x 3 columns]

# %%
# Mengubah tipe data CRSDepTime menjadi time dengan hanya menampilkan jam dan menit saja
res4['CRSDepTime'] = pd.to_datetime(res4['CRSDepTime'], format='%H:%M')
res4
# Out:
#               CRSDepTime  WindSpeed  DepDelay
# 0    1900-01-01 00:20:00  20.131367 -6.254400
# 1    1900-01-01 00:25:00  22.333333 -3.500000
# 2    1900-01-01 00:29:00  22.333333 -6.909091
# 3    1900-01-01 00:30:00  17.714286 -2.500000
# 4    1900-01-01 00:35:00  17.714286 -4.750000
# ...                  ...        ...       ...
# 1084 1900-01-01 23:49:00  19.333333 -3.000000
# 1085 1900-01-01 23:50:00  18.897436 -5.509434
# 1086 1900-01-01 23:53:00  19.333333 -5.500000
# 1087 1900-01-01 23:55:00  18.328912 -6.381963
# 1088 1900-01-01 23:59:00  19.865385 -8.130923
#
# [1089 rows x 3 columns]

# %%
# Membuat bins berdasrkan CRSDepTime dengan setiap kenaikan 3 jam, contohnya 00:00 - 03:00, 03:00 - 06:00, dst
bins = pd.date_range('1900-01-01 00:00:00', '1900-01-01 23:59:00', freq='3H')
labels = [f'{i} - {j}' for i, j in zip(bins[:-1].strftime('%H:%M'), bins[1:].strftime('%H:%M'))]
res4['CRSDepTime bin'] = pd.cut(res4['CRSDepTime'], bins=bins, labels=labels, right=False)

# %%
# groupkan berdasarkan CRSDepTime bin
res4 = res4.groupby(['CRSDepTime bin']).mean().reset_index()
res4
# Out:
# C:\Users\akmal\AppData\Local\Temp\ipykernel_11136\2697104294.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res4 = res4.groupby(['CRSDepTime bin']).mean().reset_index()
#   CRSDepTime bin  WindSpeed  DepDelay
# 0  00:00 - 03:00  17.640338 -5.451505
# 1  03:00 - 06:00  18.488994 -5.639141
# 2  06:00 - 09:00  20.101259 -5.871419
# 3  09:00 - 12:00  19.930874 -6.114506
# 4  12:00 - 15:00  19.995893 -6.097198
# 5  15:00 - 18:00  19.876782 -5.993847
# 6  18:00 - 21:00  19.116133 -6.224989

# %% [markdown]
# # Analisis Hasil

# %% [markdown]
# ## Analisis Hasil Preprocessing keterlambatan penerbangan berdasarkan waktu keberangkatan dan kondisi cuaca

# %%
res1 = res1.sort_values(by=['DepDelay'])
res1
# Out:
#   SkyCondition   DepDelay
# 3            M -14.333333
# 4          OVC -13.238743
# 7          VV0 -10.996256
# 2          FEW -10.088847
# 0          BKN -10.045542
# 6           VV -10.000000
# 5          SCT  -9.855048
# 1          CLR  -9.705683

# %%
# Tampilkan data selain bernilai M
res1 = res1[res1['SkyCondition'] != 'M']
res1
# Out:
#   SkyCondition   DepDelay
# 4          OVC -13.238743
# 7          VV0 -10.996256
# 2          FEW -10.088847
# 0          BKN -10.045542
# 6           VV -10.000000
# 5          SCT  -9.855048
# 1          CLR  -9.705683

# %%
# Membuat grafik batang
plt.figure(figsize=(10, 5))
sns.barplot(x='SkyCondition', y='DepDelay', data=res1)
plt.title('Rata-rata keterlambatan penerbangan berdasarkan kondisi cuaca')
# Out:
# Text(0.5, 1.0, 'Rata-rata keterlambatan penerbangan berdasarkan kondisi cuaca')

# %% [markdown]
# ## Analisis Hasil Preprocessing keterlambatan dengan mempertimbangkan faktor suhu udara dan aliansi penerbangan

# %%
res2 = res2.sort_values(by=['DepDelay'])
res2
# Out:
#          Aliance  DepDelay  WetBulbFarenheit
# 0         Others -7.621317         54.427226
# 3  Star Alliance -7.015094         54.607986
# 1       Sky Team -6.970896         54.782547
# 2      Southwest -6.369337         54.825378

# %%
# Membuat grafik garis WetBulbFarenheit dengan legend carrier
plt.figure(figsize=(10, 5))
sns.scatterplot(x='WetBulbFarenheit', y='DepDelay', data=res2, hue='Aliance')
sns.lineplot(x='WetBulbFarenheit', y='DepDelay', data=res2)
plt.legend(bbox_to_anchor=(1.005, 1), loc=2, borderaxespad=0., title='Aliance')
plt.grid(linestyle='--')

# %% [markdown]
# ## Analisis Hasil Preprocessing keterlambatan penerbangan berdasarkan waktu keberangkatan dan arah angin

# %%
res3.sort_values(by=['DepDelay'])
# Out:
#                 Date bins  WindDirection  DepDelay
# 4  2011-10-25--2011-10-31     173.643151 -6.819560
# 1  2011-10-07--2011-10-13     173.651232 -6.759659
# 0  2011-10-01--2011-10-07     173.619587 -6.725643
# 3  2011-10-19--2011-10-25     173.622895 -6.649834
# 2  2011-10-13--2011-10-19     173.627590 -6.540130

# %%
# Membuat grafik garis WindDirection dengan legend Date bins
plt.figure(figsize=(10, 5))
sns.scatterplot(x=res3['DepDelay'], y=res3['WindDirection'], hue=res3['Date bins'])
sns.lineplot(x=res3['DepDelay'], y=res3['WindDirection'])
plt.legend(bbox_to_anchor=(1.005, 1), loc=2, borderaxespad=0., title='Date bins')
plt.grid(linestyle='--')

# %% [markdown]
# ## Analisis Hasil Preprocessing keterlambatan penerbangan berdasarkan waktu keberangkatan dan kecepatan angin

# %%
res4
# Out:
#   CRSDepTime bin  WindSpeed  DepDelay
# 0  00:00 - 03:00  17.640338 -5.451505
# 1  03:00 - 06:00  18.488994 -5.639141
# 2  06:00 - 09:00  20.101259 -5.871419
# 3  09:00 - 12:00  19.930874 -6.114506
# 4  12:00 - 15:00  19.995893 -6.097198
# 5  15:00 - 18:00  19.876782 -5.993847
# 6  18:00 - 21:00  19.116133 -6.224989

# %%
# Membuat grafik garis WindSpeed dengan legend CRSDepTime bin
plt.figure(figsize=(10,5))
sns.scatterplot(x='DepDelay', y='WindSpeed', data=res4, hue='CRSDepTime bin')
sns.lineplot(x='DepDelay', y='WindSpeed', data=res4)
plt.legend(bbox_to_anchor=(1.005, 1), loc=2, borderaxespad=0., title='CRSDepTime bins')
plt.grid(linestyle='--')
